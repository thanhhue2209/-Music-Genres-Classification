# %% [markdown]
# ## Wavelet data generation..

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
import librosa
import librosa.display

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout, GlobalAveragePooling2D 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
spectrogram_path = '/kaggle/input/dl-final-musicgenreclassification-dataset/data/spectrogram'
wavelets_path = '/kaggle/input/dl-final-musicgenreclassification-dataset/data/wavelets'

# %% [markdown]
# # Load data

# %%
labels = os.listdir('/kaggle/input/dl-final-musicgenreclassification-dataset/data/spectrogram/train')

# %%
img_size = 256

def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data(os.path.join(spectrogram_path, 'train'))
val = get_data(os.path.join(spectrogram_path, 'test'))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   from ipykernel import kernelapp as app

# %%
x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        #rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        #horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# # Model

# %% [markdown]
# ## CNN

# %%
model = Sequential()
model.add(Conv2D(32,3,padding="same", activation="relu", input_shape=(256,256,3)))
model.add(MaxPool2D())

model.add(Conv2D(32, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(10, activation="softmax"))

model.summary()
# Out:
# 2022-12-11 14:34:16.198025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-11 14:34:16.289707: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-11 14:34:16.290523: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-11 14:34:16.291734: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-11 14:34:16.292079: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-11 14:34:16.292787: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-11 14:34:16.293437: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-11 14:34:18.573901: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-11 14:34:18.574837: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-11 14:34:18.575692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-11 14:34:18.576299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8388736
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 8,418,666
# Trainable params: 8,418,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(lr=0.0001)
model.compile(optimizer = opt , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics = ['accuracy'])
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
history = model.fit(x_train,y_train,epochs = 100, validation_data = (x_val, y_val))
# Out:
# Epoch 1/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0078 - accuracy: 0.9986 - val_loss: 3.9857 - val_accuracy: 0.3633
# Epoch 2/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0175 - accuracy: 0.9971 - val_loss: 3.9094 - val_accuracy: 0.3633
# Epoch 3/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 3.9419 - val_accuracy: 0.3400
# Epoch 4/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0099 - accuracy: 0.9986 - val_loss: 3.8639 - val_accuracy: 0.3833
# Epoch 5/100
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0126 - accuracy: 0.9971 - val_loss: 3.9209 - val_accuracy: 0.3700
# Epoch 6/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0151 - accuracy: 0.9971 - val_loss: 3.7808 - val_accuracy: 0.3533
# Epoch 7/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0151 - accuracy: 0.9971 - val_loss: 3.8268 - val_accuracy: 0.3533
# Epoch 8/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0116 - accuracy: 0.9971 - val_loss: 3.6986 - val_accuracy: 0.3600
# Epoch 9/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0103 - accuracy: 0.9986 - val_loss: 3.8292 - val_accuracy: 0.3700
# Epoch 10/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0155 - accuracy: 0.9986 - val_loss: 4.1087 - val_accuracy: 0.3467
# Epoch 11/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0097 - accuracy: 0.9971 - val_loss: 3.7978 - val_accuracy: 0.3600
# Epoch 12/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0087 - accuracy: 0.9986 - val_loss: 3.8258 - val_accuracy: 0.3833
# Epoch 13/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0143 - accuracy: 0.9971 - val_loss: 3.8555 - val_accuracy: 0.3367
# Epoch 14/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0080 - accuracy: 0.9986 - val_loss: 3.9806 - val_accuracy: 0.3800
# Epoch 15/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 3.8808 - val_accuracy: 0.3667
# Epoch 16/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0139 - accuracy: 0.9971 - val_loss: 3.7557 - val_accuracy: 0.3633
# Epoch 17/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0074 - accuracy: 0.9986 - val_loss: 3.8631 - val_accuracy: 0.3633
# Epoch 18/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.8547 - val_accuracy: 0.3633
# Epoch 19/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0084 - accuracy: 0.9986 - val_loss: 3.8578 - val_accuracy: 0.3633
# Epoch 20/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0103 - accuracy: 0.9986 - val_loss: 3.9597 - val_accuracy: 0.3567
# Epoch 21/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 4.0767 - val_accuracy: 0.3667
# Epoch 22/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 3.9789 - val_accuracy: 0.3567
# Epoch 23/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0140 - accuracy: 0.9971 - val_loss: 3.9777 - val_accuracy: 0.3800
# Epoch 24/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 3.8622 - val_accuracy: 0.3567
# Epoch 25/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 3.7861 - val_accuracy: 0.3467
# Epoch 26/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0104 - accuracy: 0.9971 - val_loss: 3.7306 - val_accuracy: 0.3533
# Epoch 27/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 3.6929 - val_accuracy: 0.3600
# Epoch 28/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 3.8557 - val_accuracy: 0.3767
# Epoch 29/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 3.8206 - val_accuracy: 0.3700
# Epoch 30/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 3.9813 - val_accuracy: 0.3700
# Epoch 31/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0066 - accuracy: 0.9986 - val_loss: 3.9330 - val_accuracy: 0.3600
# Epoch 32/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0173 - accuracy: 0.9971 - val_loss: 3.8577 - val_accuracy: 0.3500
# Epoch 33/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0074 - accuracy: 0.9986 - val_loss: 3.8723 - val_accuracy: 0.3767
# Epoch 34/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0110 - accuracy: 0.9986 - val_loss: 3.9143 - val_accuracy: 0.3567
# Epoch 35/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.9039 - val_accuracy: 0.3533
# Epoch 36/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 4.0066 - val_accuracy: 0.3667
# Epoch 37/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 3.8395 - val_accuracy: 0.3767
# Epoch 38/100
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 3.9200 - val_accuracy: 0.3800
# Epoch 39/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0082 - accuracy: 0.9986 - val_loss: 3.9774 - val_accuracy: 0.3700
# Epoch 40/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0066 - accuracy: 0.9986 - val_loss: 3.9216 - val_accuracy: 0.3533
# Epoch 41/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0091 - accuracy: 0.9986 - val_loss: 4.0404 - val_accuracy: 0.3733
# Epoch 42/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 3.9379 - val_accuracy: 0.3633
# Epoch 43/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0167 - accuracy: 0.9971 - val_loss: 3.7546 - val_accuracy: 0.3800
# Epoch 44/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 3.9866 - val_accuracy: 0.3433
# Epoch 45/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0144 - accuracy: 0.9971 - val_loss: 3.7449 - val_accuracy: 0.3767
# Epoch 46/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0094 - accuracy: 0.9986 - val_loss: 3.8666 - val_accuracy: 0.3500
# Epoch 47/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0051 - accuracy: 0.9971 - val_loss: 3.9584 - val_accuracy: 0.3700
# Epoch 48/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0080 - accuracy: 0.9986 - val_loss: 4.0767 - val_accuracy: 0.3767
# Epoch 49/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0157 - accuracy: 0.9971 - val_loss: 3.9427 - val_accuracy: 0.3600
# Epoch 50/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 3.7207 - val_accuracy: 0.3600
# Epoch 51/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0138 - accuracy: 0.9971 - val_loss: 3.8690 - val_accuracy: 0.3433
# Epoch 52/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0115 - accuracy: 0.9986 - val_loss: 3.8270 - val_accuracy: 0.3733
# Epoch 53/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0088 - accuracy: 0.9986 - val_loss: 3.9110 - val_accuracy: 0.3333
# Epoch 54/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0108 - accuracy: 0.9986 - val_loss: 3.8980 - val_accuracy: 0.3800
# Epoch 55/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 3.8529 - val_accuracy: 0.3567
# Epoch 56/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0091 - accuracy: 0.9986 - val_loss: 3.8387 - val_accuracy: 0.3567
# Epoch 57/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0092 - accuracy: 0.9986 - val_loss: 3.8667 - val_accuracy: 0.3633
# Epoch 58/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0129 - accuracy: 0.9986 - val_loss: 3.7545 - val_accuracy: 0.3567
# Epoch 59/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0140 - accuracy: 0.9971 - val_loss: 3.7782 - val_accuracy: 0.3467
# Epoch 60/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0064 - accuracy: 0.9971 - val_loss: 3.8028 - val_accuracy: 0.3567
# Epoch 61/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0147 - accuracy: 0.9971 - val_loss: 3.8229 - val_accuracy: 0.3467
# Epoch 62/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0179 - accuracy: 0.9943 - val_loss: 4.5012 - val_accuracy: 0.3100
# Epoch 63/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0113 - accuracy: 0.9957 - val_loss: 3.8644 - val_accuracy: 0.3400
# Epoch 64/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0072 - accuracy: 0.9986 - val_loss: 4.0507 - val_accuracy: 0.3500
# Epoch 65/100
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0078 - accuracy: 0.9986 - val_loss: 3.9425 - val_accuracy: 0.3667
# Epoch 66/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0080 - accuracy: 0.9986 - val_loss: 3.8543 - val_accuracy: 0.3533
# Epoch 67/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0065 - accuracy: 0.9986 - val_loss: 3.8629 - val_accuracy: 0.3500
# Epoch 68/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 3.7871 - val_accuracy: 0.3600
# Epoch 69/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0088 - accuracy: 0.9986 - val_loss: 3.8727 - val_accuracy: 0.3700
# Epoch 70/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 3.8385 - val_accuracy: 0.3500
# Epoch 71/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 3.7913 - val_accuracy: 0.3533
# Epoch 72/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 3.8232 - val_accuracy: 0.3567
# Epoch 73/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0106 - accuracy: 0.9986 - val_loss: 3.8387 - val_accuracy: 0.3467
# Epoch 74/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0030 - accuracy: 0.9986 - val_loss: 3.8827 - val_accuracy: 0.3400
# Epoch 75/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0027 - accuracy: 0.9986 - val_loss: 3.9223 - val_accuracy: 0.3533
# Epoch 76/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0094 - accuracy: 0.9986 - val_loss: 3.9886 - val_accuracy: 0.3700
# Epoch 77/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0092 - accuracy: 0.9986 - val_loss: 3.8231 - val_accuracy: 0.3567
# Epoch 78/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 3.8837 - val_accuracy: 0.3600
# Epoch 79/100
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0104 - accuracy: 0.9986 - val_loss: 3.9224 - val_accuracy: 0.3600
# Epoch 80/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 4.0022 - val_accuracy: 0.3633
# Epoch 81/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0063 - accuracy: 0.9986 - val_loss: 4.1762 - val_accuracy: 0.3633
# Epoch 82/100
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0098 - accuracy: 0.9986 - val_loss: 3.9638 - val_accuracy: 0.3600
# Epoch 83/100
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0115 - accuracy: 0.9971 - val_loss: 3.8581 - val_accuracy: 0.3533
# Epoch 84/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0130 - accuracy: 0.9971 - val_loss: 3.9046 - val_accuracy: 0.3700
# Epoch 85/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 3.8969 - val_accuracy: 0.3600
# Epoch 86/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 3.9292 - val_accuracy: 0.3467
# Epoch 87/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0142 - accuracy: 0.9971 - val_loss: 3.8282 - val_accuracy: 0.3667
# Epoch 88/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.8040 - val_accuracy: 0.3567
# Epoch 89/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0068 - accuracy: 0.9986 - val_loss: 3.8660 - val_accuracy: 0.3667
# Epoch 90/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 4.0010 - val_accuracy: 0.3500
# Epoch 91/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0069 - accuracy: 0.9971 - val_loss: 3.8347 - val_accuracy: 0.3567
# Epoch 92/100
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 3.8976 - val_accuracy: 0.3633
# Epoch 93/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0112 - accuracy: 0.9986 - val_loss: 3.9192 - val_accuracy: 0.3467
# Epoch 94/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0075 - accuracy: 0.9986 - val_loss: 3.8753 - val_accuracy: 0.3733
# Epoch 95/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0097 - accuracy: 0.9986 - val_loss: 3.7725 - val_accuracy: 0.3767
# Epoch 96/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.8239 - val_accuracy: 0.3633
# Epoch 97/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 3.8423 - val_accuracy: 0.3633
# Epoch 98/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0089 - accuracy: 0.9986 - val_loss: 3.9559 - val_accuracy: 0.3633
# Epoch 99/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0107 - accuracy: 0.9986 - val_loss: 3.7955 - val_accuracy: 0.3500
# Epoch 100/100
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0083 - accuracy: 0.9986 - val_loss: 3.8031 - val_accuracy: 0.3633

# %%
import pickle
model.save_weights('500_epoch_simple_lr.cpkt')

pickle.dump(history.history, open('history_500_epoch_simple.pkl','wb'))

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(100)

plt.figure(figsize=(25, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import pickle
history = pickle.load(open('history_500_epoch_simple.pkl','rb'))
acc = history['accuracy']
val_acc = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

epochs_range = range(100)
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,6))
plt.rc('xtick', labelsize=10)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10)
ax1.plot(epochs_range, acc, label='Training Accuracy', c = '#4CAF50', linewidth=4)
ax1.plot(epochs_range, val_acc, label='Validation Accuracy', c='red', linewidth=4)
ax1.legend()
ax1.set_title('Training and Validation Accuracy',fontsize=18)
ax1.set_ylabel('Accuracy',fontsize=18)
ax1.set_xlabel('Epoch',fontsize=18)

ax2.plot(epochs_range, loss, label='Training Loss',c = '#4CAF50', linewidth=4)
ax2.plot(epochs_range, val_loss, label='Validation Loss', c='red', linewidth=4)
ax2.legend()
ax2.set_title('Training and Validation Loss',fontsize=18)
ax2.set_ylabel('Loss',fontsize=18)
ax2.set_xlabel('Epoch',fontsize=18)
fig.tight_layout(pad=3.0)
plt.show()
# plt.savefig('sim_plot1.png',bbox_inches = 'tight')
plt.clf()

# %%
predictions = model.predict(x_val)
predictions = np.argmax(predictions,axis=1)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#        disco       0.41      0.63      0.50        30
#        metal       0.59      0.67      0.62        30
#       reggae       0.46      0.37      0.41        30
#        blues       0.09      0.07      0.08        30
#         rock       0.06      0.03      0.04        30
#    classical       0.72      0.60      0.65        30
#         jazz       0.40      0.47      0.43        30
#       hiphop       0.20      0.17      0.18        30
#      country       0.18      0.27      0.22        30
#          pop       0.38      0.37      0.37        30
#
#     accuracy                           0.36       300
#    macro avg       0.35      0.36      0.35       300
# weighted avg       0.35      0.36      0.35       300

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
cm1 = confusion_matrix(y_val, predictions)
df_cm = pd.DataFrame(cm1, index = [i for i in labels],
              columns = [i for i in labels])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True,cmap="RdPu")
# plt.savefig('confusion_mrtx1.png',bbox_inches = 'tight')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Transfer Learning based modeling

# %%
base_model = tf.keras.applications.InceptionResNetV2(
    input_shape = (256, 256, 3), 
    include_top = False,
    weights = "imagenet"
)
# Out:
# 2022-12-12 15:29:09.495860: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-12 15:29:09.664049: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-12 15:29:09.665116: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-12 15:29:09.667358: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-12 15:29:09.667759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-12 15:29:09.668598: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-12 15:29:09.669459: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-12 15:29:12.018930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-12 15:29:12.020407: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-12 15:29:12.021362: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-12 15:29:12.022067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 1s 0us/step
# 219070464/219055592 [==============================] - 1s 0us/step

# %%
base_model.trainable = False
model = tf.keras.Sequential(
    [
        base_model,
        GlobalAveragePooling2D(),
        Dropout(0.2),
        Dense(512, activation='relu'),
        Dropout(0.3),
        BatchNormalization(),
        Dense(256, activation='relu'),
        Dropout(0.3),
        Dense(10, activation="softmax")
    ]
)

# %%
base_learning_rate = 0.0001

sgd = SGD(learning_rate=10e-3, momentum=0.9, decay=0.000001)

reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy', 
    mode='min',
    factor=0.2,
    patience=3, 
    min_lr=1e-15,
    verbose=1
)

early_stp = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    verbose=1
)

model.compile(
    optimizer=sgd,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

history1 = model.fit(
    x_train,
    y_train,
    epochs = 500,
    validation_data = (x_val, y_val),
    callbacks=[reduce_lr, early_stp]
)
# Out:
# Epoch 1/500
# 22/22 [==============================] - 17s 346ms/step - loss: 1.8803 - accuracy: 0.3262 - val_loss: 2.1697 - val_accuracy: 0.2900
# Epoch 2/500
# 22/22 [==============================] - 4s 203ms/step - loss: 2.0289 - accuracy: 0.3505 - val_loss: 2.0963 - val_accuracy: 0.2800
# Epoch 3/500
# 22/22 [==============================] - 4s 200ms/step - loss: 2.0514 - accuracy: 0.3262 - val_loss: 2.3760 - val_accuracy: 0.3133
# Epoch 4/500
# 22/22 [==============================] - 4s 206ms/step - loss: 2.1021 - accuracy: 0.3205 - val_loss: 2.0764 - val_accuracy: 0.3433
# Epoch 5/500
# 22/22 [==============================] - 4s 202ms/step - loss: 1.8714 - accuracy: 0.3705 - val_loss: 2.1075 - val_accuracy: 0.2733
# Epoch 6/500
# 22/22 [==============================] - 4s 200ms/step - loss: 1.9367 - accuracy: 0.3605 - val_loss: 2.0276 - val_accuracy: 0.2767
# Epoch 7/500
# 22/22 [==============================] - 4s 202ms/step - loss: 1.8882 - accuracy: 0.3491 - val_loss: 2.2023 - val_accuracy: 0.3500
# Epoch 8/500
# 22/22 [==============================] - 4s 200ms/step - loss: 1.9803 - accuracy: 0.3519 - val_loss: 2.1956 - val_accuracy: 0.3167
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 9/500
# 22/22 [==============================] - 4s 201ms/step - loss: 1.9300 - accuracy: 0.3562 - val_loss: 1.8025 - val_accuracy: 0.3767
# Epoch 10/500
# 22/22 [==============================] - 4s 200ms/step - loss: 1.6347 - accuracy: 0.3934 - val_loss: 1.8027 - val_accuracy: 0.3800
# Epoch 11/500
# 22/22 [==============================] - 4s 206ms/step - loss: 1.6699 - accuracy: 0.3963 - val_loss: 1.8703 - val_accuracy: 0.3500
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 12/500
# 22/22 [==============================] - 4s 200ms/step - loss: 1.6384 - accuracy: 0.4177 - val_loss: 1.7274 - val_accuracy: 0.4367
# Epoch 13/500
# 22/22 [==============================] - 6s 260ms/step - loss: 1.5408 - accuracy: 0.4349 - val_loss: 1.7004 - val_accuracy: 0.4133
# Epoch 14/500
# 22/22 [==============================] - 4s 200ms/step - loss: 1.5262 - accuracy: 0.4564 - val_loss: 1.7032 - val_accuracy: 0.4200
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 15/500
# 22/22 [==============================] - 4s 198ms/step - loss: 1.5587 - accuracy: 0.4421 - val_loss: 1.7037 - val_accuracy: 0.4267
# Epoch 16/500
# 22/22 [==============================] - 4s 200ms/step - loss: 1.5183 - accuracy: 0.4521 - val_loss: 1.6987 - val_accuracy: 0.4300
# Epoch 17/500
# 22/22 [==============================] - 6s 263ms/step - loss: 1.5138 - accuracy: 0.4521 - val_loss: 1.6981 - val_accuracy: 0.4267
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 18/500
# 22/22 [==============================] - 4s 204ms/step - loss: 1.5189 - accuracy: 0.4521 - val_loss: 1.6983 - val_accuracy: 0.4267
# Epoch 19/500
# 22/22 [==============================] - 4s 204ms/step - loss: 1.5254 - accuracy: 0.4635 - val_loss: 1.6985 - val_accuracy: 0.4267
# Epoch 20/500
# 22/22 [==============================] - 4s 198ms/step - loss: 1.5022 - accuracy: 0.4449 - val_loss: 1.6984 - val_accuracy: 0.4267
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 21/500
# 22/22 [==============================] - 4s 199ms/step - loss: 1.5106 - accuracy: 0.4835 - val_loss: 1.6983 - val_accuracy: 0.4267
# Epoch 22/500
# 22/22 [==============================] - 4s 200ms/step - loss: 1.5184 - accuracy: 0.4692 - val_loss: 1.6984 - val_accuracy: 0.4267
# Epoch 00022: early stopping

# %%
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']
loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs_range = range(500)

plt.figure(figsize=(25, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import pickle
history = pickle.load(open('history_500_epoch_tr.pkl','rb'))
acc = history['accuracy']
val_acc = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

epochs_range = range(500)
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,6))
plt.rc('xtick', labelsize=10)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10)
ax1.plot(epochs_range, acc, label='Training Accuracy', c = '#4CAF50', linewidth=4)
ax1.plot(epochs_range, val_acc, label='Validation Accuracy', c='red', linewidth=4)
ax1.legend()
ax1.set_title('Training and Validation Accuracy',fontsize=18)
ax1.set_ylabel('Accuracy',fontsize=18)
ax1.set_xlabel('Epoch',fontsize=18)

ax2.plot(epochs_range, loss, label='Training Loss',c = '#4CAF50', linewidth=4)
ax2.plot(epochs_range, val_loss, label='Validation Loss', c='red', linewidth=4)
ax2.legend()
ax2.set_title('Training and Validation Loss',fontsize=18)
ax2.set_ylabel('Loss',fontsize=18)
ax2.set_xlabel('Epoch',fontsize=18)
fig.tight_layout(pad=3.0)
#plt.show()
# plt.savefig('tfr_plot1.png',bbox_inches = 'tight')
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_24/910014714.py in <module>
#       1 import pickle
# ----> 2 history = pickle.load(open('history_500_epoch_tr.pkl','rb'))
#       3 acc = history['accuracy']
#       4 val_acc = history['val_accuracy']
#       5 loss = history['loss']
#
# FileNotFoundError: [Errno 2] No such file or directory: 'history_500_epoch_tr.pkl'

# %%
predictions = model.predict_classes(x_val)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = labels))

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
cm1 = confusion_matrix(y_val, predictions)
df_cm = pd.DataFrame(cm1, index = [i for i in labels],
              columns = [i for i in labels])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True,cmap="RdPu")
plt.savefig('confusion_mrtx2.png',bbox_inches = 'tight')

# %%
model.save_weights('500_epoch_transfer_lr.cpkt')
pickle.dump(history1.history, open('history_500_epoch_tr.pkl','wb'))

# %% [markdown]
# ## Multi-Model Training

# %%
sp_train = get_data(os.path.join(spectrogram_path, 'train'))
sp_val = get_data(os.path.join(spectrogram_path, 'test'))

wv_train = get_data(os.path.join(wavelets_path, 'train'))
wv_val = get_data(os.path.join(wavelets_path, 'test'))

# %%
x_sp_train = []
y_sp_train = []
x_sp_val = []
y_sp_val = []

for feature, label in sp_train:
    x_sp_train.append(feature)
    y_sp_train.append(label)

for feature, label in sp_val:
    x_sp_val.append(feature)
    y_sp_val.append(label)

# Normalize the data
x_sp_train = np.array(x_sp_train) / 255
x_sp_val = np.array(x_sp_val) / 255

x_sp_train.reshape(-1, img_size, img_size, 1)
y_sp_train = np.array(y_sp_train)

x_sp_val.reshape(-1, img_size, img_size, 1)
y_sp_val = np.array(y_sp_val)

# %%
x_wv_train = []
y_wv_train = []
x_wv_val = []
y_wv_val = []

for feature, label in wv_train:
    x_wv_train.append(feature)
    y_wv_train.append(label)

for feature, label in wv_val:
    x_wv_val.append(feature)
    y_wv_val.append(label)

# Normalize the data
x_wv_train = np.array(x_wv_train) / 255
x_wv_val = np.array(x_wv_val) / 255

x_wv_train.reshape(-1, img_size, img_size, 1)
y_wv_train = np.array(y_wv_train)

x_wv_val.reshape(-1, img_size, img_size, 1)
y_wv_val = np.array(y_wv_val)

# %%
datagen_sp = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        #rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        #horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen_sp.fit(x_sp_train)

datagen_wv = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        #rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        #horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen_wv.fit(x_wv_train)

# %%
input_sp = keras.Input(shape=(256,256,3))
input_wv = keras.Input(shape=(256,256,3))

x = Conv2D(32,3,padding="same", activation="relu")(input_sp)
x = MaxPool2D()(x)
x = Conv2D(64, 3, padding="same", activation="relu")(x)
x = MaxPool2D()(x)
x = Dropout(0.4)(x)
x = Flatten()(x)
x = Dense(128,activation="relu")(x)
x = keras.Model(inputs=input_sp, outputs=x)

y = Conv2D(32,3,padding="same", activation="relu")(input_wv)
y = MaxPool2D()(y)
y = Conv2D(64, 3, padding="same", activation="relu")(y)
y = MaxPool2D()(y)
y = Dropout(0.4)(y)
y = Flatten()(y)
y = Dense(128,activation="relu")(y)
y = keras.Model(inputs=input_wv, outputs=y)

from tensorflow.keras.layers import concatenate
combined = concatenate([x.output, y.output])

z = Dense(32, activation="relu")(combined)
z = Dense(10, activation="softmax")(z)

model = keras.Model(inputs=[x.input, y.input], outputs=z)

# %%
model.summary()

# %%
opt = Adam(lr=0.0001)
model.compile(optimizer = opt , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics = ['accuracy'])

# %%
history2 = model.fit([x_sp_train,x_wv_train],y_sp_train,epochs = 500, validation_data = ([x_sp_val,x_wv_val], y_sp_val))
import pickle
model.save_weights('500_epoch_multi_lr.cpkt')
pickle.dump(history2.history, open('history_500_epoch_multi.pkl','wb'))

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs_range = range(500)

plt.figure(figsize=(25, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import pickle
history = pickle.load(open('history_500_epoch_multi.pkl','rb'))
acc = history['accuracy']
val_acc = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

epochs_range = range(500)
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,6))
plt.rc('xtick', labelsize=10)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10)
ax1.plot(epochs_range, acc, label='Training Accuracy', c = '#4CAF50', linewidth=4)
ax1.plot(epochs_range, val_acc, label='Validation Accuracy', c='red', linewidth=4)
ax1.legend()
ax1.set_title('Training and Validation Accuracy',fontsize=18)
ax1.set_ylabel('Accuracy',fontsize=18)
ax1.set_xlabel('Epoch',fontsize=18)

ax2.plot(epochs_range, loss, label='Training Loss',c = '#4CAF50', linewidth=4)
ax2.plot(epochs_range, val_loss, label='Validation Loss', c='red', linewidth=4)
ax2.legend()
ax2.set_title('Training and Validation Loss',fontsize=18)
ax2.set_ylabel('Loss',fontsize=18)
ax2.set_xlabel('Epoch',fontsize=18)
fig.tight_layout(pad=3.0)
#plt.show()
plt.savefig('multi_plot1.png',bbox_inches = 'tight')
plt.clf()

# %%
predictions = model.predict([x_sp_val,x_wv_val])
print(classification_report(y_wv_val, np.argmax(predictions, axis=1), target_names = labels))

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
predictions = np.argmax(predictions, axis=1)
cm1 = confusion_matrix(y_val, predictions)
df_cm = pd.DataFrame(cm1, index = [i for i in labels],
              columns = [i for i in labels])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True,cmap="RdPu")
plt.savefig('confusion_mrtx3.png',bbox_inches = 'tight')

# %%
epochs_range = range(500)
import matplotlib.pyplot as plt
import pickle 
history = pickle.load(open('history_500_epoch_simple.pkl','rb'))
acc = history['accuracy']
val_acc = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']

history = pickle.load(open('history_500_epoch_tr.pkl','rb'))
acc1 = history['accuracy']
val_acc1 = history['val_accuracy']
loss1 = history['loss']
val_loss1 = history['val_loss']

history = pickle.load(open('history_500_epoch_multi.pkl','rb'))
acc2 = history['accuracy']
val_acc2 = history['val_accuracy']
loss2 = history['loss']
val_loss2 = history['val_loss']

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,6))
plt.rc('xtick', labelsize=10)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10)
ax1.plot(epochs_range, acc, label='CNN Training Accuracy', c = '#4CAF50', linewidth=4)
ax1.plot(epochs_range, val_acc, label='CNN Validation Accuracy', c='red', linewidth=4)
ax1.plot(epochs_range, acc1, label='Transfer learning Training Accuracy', c = '#e72866', linewidth=4)
ax1.plot(epochs_range, val_acc1, label='Transfer learning Validation Accuracy', c='#282ec7', linewidth=4)
ax1.plot(epochs_range, acc2, label='Multi modal Training Accuracy', c = '#171c1c', linewidth=4)
ax1.plot(epochs_range, val_acc2, label='Multi modal Validation Accuracy', c='#62176e', linewidth=4)

ax1.legend()
ax1.set_title('Training and Validation Accuracy',fontsize=18)
ax1.set_ylabel('Accuracy',fontsize=18)
ax1.set_xlabel('Epoch',fontsize=18)

ax2.plot(epochs_range, loss, label='CNN Training Loss',c = '#4CAF50', linewidth=4)
ax2.plot(epochs_range, val_loss, label='CNN Validation Loss', c='red', linewidth=4)
ax2.plot(epochs_range, loss1, label='Transfer learning Training Loss',c = '#c72866', linewidth=4)
ax2.plot(epochs_range, val_loss1, label='Transfer learning Validation Loss', c='#282ec7', linewidth=4)
ax2.plot(epochs_range, loss2, label='Multi modal Training Loss',c = '#171c1c', linewidth=4)
ax2.plot(epochs_range, val_loss2, label='Multi modal learning Validation Loss', c='#62176e', linewidth=4)

ax2.legend()
ax2.set_title('Training and Validation Loss',fontsize=18)
ax2.set_ylabel('Loss',fontsize=18)
ax2.set_xlabel('Epoch',fontsize=18)
fig.tight_layout(pad=3.0)
#plt.show()
plt.savefig('all_1.png',bbox_inches = 'tight')
plt.clf()
